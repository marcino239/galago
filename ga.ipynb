# %%
import numpy as np

from matplotlib import pyplot as plt
from ga import run_optimisation

# %matplotlib inline

# %%
g, perf = run_optimisation( MAX_EPOCHS = 100 )
# Out:
# 0:	297.3546776000717	-0.05212373897614142,0.14553925072525342
# /home/marcino/work/galago/ga.py:60: RuntimeWarning: invalid value encountered in add
#   y = np.sin( T * w + p )
# /home/marcino/work/galago/ga.py:60: RuntimeWarning: invalid value encountered in multiply
#   y = np.sin( T * w + p )
# /home/marcino/work/galago/ga.py:60: RuntimeWarning: overflow encountered in multiply
#   y = np.sin( T * w + p )
# /home/marcino/work/galago/ga.py:60: RuntimeWarning: invalid value encountered in sin
#   y = np.sin( T * w + p )
# 1:	297.3546776000717	-0.05212373897614142,0.14553925072525342
# 2:	297.3546776000717	-0.05212373897614142,0.14553925072525342
# 3:	270.2556321364146	-2.8643477189307625,1.3364513237799067
# 4:	159.67583912134344	-2.9229917470456837,1.7652687454704026
# 5:	159.67583912134344	-2.9229917470456837,1.7652687454704026
# 6:	77.538260185491	-2.8643477240464623,4237.104622202496
# 7:	77.538260185491	-2.8643477240464623,4237.104622202496
# ...

# %%
x = list( map( lambda x: x[0], perf ) )
y = list( map( lambda x: x[1], perf ) )

plt.semilogy( x, y )
plt.xlabel( 'epoch' )
plt.ylabel( 'error' )
# Out:
# Text(0,0.5,'error')
